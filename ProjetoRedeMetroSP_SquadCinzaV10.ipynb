# %% [markdown]
# # Projeto Rede Metro SP
# Rede de transporte metropolitano SP - O projeto do módulo 2 consiste em modelar a rede de transporte metropolitano de SP como um grafo!
#
# <img src="img/Mapa.png" style="width:350px;" >

# %%
import numpy  as np
import pandas as pd 
from geopy.distance import geodesic
import plotly_express as px
from numpy import genfromtxt
import json
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path =path = "datasets\Projeto_linhas.xlsx"
df = pd.read_excel(path, sheet_name='Linhas')
df.shape
#df[df['linha']=='Corredor - A2']
#df[df['linha']==linha]['Tempo Medio']
df.dtypes
# Out:
# ordem            int64
# Tempo Medio      int64
# estacao         object
# linha           object
# tipo            object
# lat            float64
# long           float64
# dtype: object

# %%
G = nx.DiGraph()

# %%
import matplotlib.pyplot as plt

# %%
dic_grafos = {}
dic_grafos_pos = {}
dic_conexoes = {}

for estacao in df.values:
    G.add_node(estacao[3])
    dic_grafos_pos[estacao[3]] ={}
df['Tempo Medio'] = df['Tempo Medio'].apply(lambda x: int(x))
for linha in df['linha'].unique().tolist():
    g = nx.DiGraph()
    listEst = df[df['linha']==linha]['estacao'].unique().tolist()
    
    g.add_nodes_from(listEst)
    for cnt in range(len(listEst)-1):
        print(listEst[cnt])
        listEstW = df[(df['linha']==linha) & (df['estacao']==listEst[cnt])]['Tempo Medio']
        print(listEstW)
        
        g.add_edge(listEst[cnt], listEst[cnt+1], weight=int(listEstW))
        g.add_edge(listEst[cnt+1], listEst[cnt], weight=int(listEstW))
    dic_grafos[linha] = g 
    
        #g.add_edge(listEst[cnt], listEst[cnt+1]) 

for linha in df['linha'].unique().tolist():
    listEst = df[df['linha']==linha]['estacao'].unique().tolist()
    df_e = df[df['linha']==linha]
    for cnt, e in df_e.iterrows():
        dic_grafos_pos[linha][e['estacao']] =  [ e['long'], e['lat']]

# print(dic_grafos['1 - Azul'])
# g = dic_grafos['1 - Azul']
# pos = dic_grafos_pos['1 - Azul']
# print(pos)
# # top = nx.bipartite.sets(g)[0]
# # pos = nx.bipartite_layout(g, top)
# nx.draw_networkx(g, pos=pos, node_color="blue", node_size=210, font_color='gray')
# # Set margins for the axes so that nodes aren't clipped
# ax = plt.gca()
# ax.margins(0.20)
# plt.axis("off")
# plt.show()
# print(dic_grafos['2 - Verde'])
# g = dic_grafos['2 - Verde']
# pos = dic_grafos_pos['2 - Verde']
# print(pos)
# # top = nx.bipartite.sets(g)[0]
# # pos = nx.bipartite_layout(g, top)
# nx.draw_networkx(g, pos=pos, node_color="green", node_size=210, font_color='gray')
# # Set margins for the axes so that nodes aren't clipped
# ax = plt.gca()
# ax.margins(0.20)
# plt.axis("off")
# plt.show()
def replace_words(s, words):
    for k, v in words.items():
        s = s.replace(k, v)
    return s

def plotLine(nomeLinha):
    colordict = {'1 - Azul': 'blue',
                 '2 - Verde':'#07785c',
                 '3 - Vermelha':'#ef4136',
                 '4 - Amarela':'yellow',
                 '5 - Lilas':'#ba43a1',
                 '7 - Rubi':'#9b1b68',
                 '8 - Cinza':'#a3a49c',
                 '9 - Esmeralda':'#0aa690',
                 '10 - Turquesa':'#027d8c',
                 '11 - Coral':'#eb5523',
                 '12 - Safira':'#0a3f85',
                 '13 - Jade':'#1f9028',
                 '15 - Prata':'#8a8e8a',
                 'Corredor - A':'blue',
                 'Corredor - @1':'blue',
                 'Corredor - @2':'blue',
                 'Corredor - B':'blue',
                 'Corredor - C':'blue'
}
    coltable = replace_words(nomeLinha,colordict)
    #print(dic_grafos[nomeLinha])
    g = dic_grafos[nomeLinha]
    pos = dic_grafos_pos[nomeLinha]
    # print(pos)
    # top = nx.bipartite.sets(g)[0]
    # pos = nx.bipartite_layout(g, top)
    #nx.draw_networkx_labels(g, label_pos=, pos=pos, rotation='vertical')
    nx.draw_networkx(g, pos=pos, node_color=coltable, node_size=210, font_color='gray',with_labels=True)
    # Set margins for the axes so that nodes aren't clipped
    ax = plt.gca()
    plt.title(nomeLinha)
    ax.margins(0.20)
    plt.axis("off")
    plt.show()
    
for linha in df['linha'].unique().tolist():
    plotLine(linha)
# Out:
# tucuruvi
# 0    0
# Name: Tempo Medio, dtype: int64
# paradainglesa
# 1    2
# Name: Tempo Medio, dtype: int64
# jardimsaopaulo-ayrtonsenna
# 2    2
# Name: Tempo Medio, dtype: int64
# santana
# 3    2
# Name: Tempo Medio, dtype: int64
# carandiru
# 4    1
# Name: Tempo Medio, dtype: int64
# portuguesa-tiete
# 5    2
# Name: Tempo Medio, dtype: int64
# armênia
# 6    2
# Name: Tempo Medio, dtype: int64
# tiradentes
# 7    2
# Name: Tempo Medio, dtype: int64
# luz
# 8    2
# Name: Tempo Medio, dtype: int64
# saobento
# 9    2
# Name: Tempo Medio, dtype: int64
# se
# 10    1
# Name: Tempo Medio, dtype: int64
# japao-liberdade
# 11    2
# Name: Tempo Medio, dtype: int64
# saojoaquim
# 12    2
# Name: Tempo Medio, dtype: int64
# vergueiro
# 13    2
# Name: Tempo Medio, dtype: int64
# paraiso
# 14    2
# Name: Tempo Medio, dtype: int64
# anarosa
# 15    1
# Name: Tempo Medio, dtype: int64
# vilamariana
# 16    2
# Name: Tempo Medio, dtype: int64
# santacruz
# 17    2
# Name: Tempo Medio, dtype: int64
# pracadaarvore
# 18    2
# Name: Tempo Medio, dtype: int64
# saude
# 19    1
# Name: Tempo Medio, dtype: int64
# saojudas
# 20    2
# Name: Tempo Medio, dtype: int64
# conceicao
# 21    2
# Name: Tempo Medio, dtype: int64
# vilamadalena
# 23    0
# Name: Tempo Medio, dtype: int64
# santuarion.sra.defatima-sumare
# 24    2
# Name: Tempo Medio, dtype: int64
# clinicas
# 25    2
# Name: Tempo Medio, dtype: int64
# consolacao
# 26    2
# Name: Tempo Medio, dtype: int64
# trianon-masp
# 27    2
# Name: Tempo Medio, dtype: int64
# metrôbrigadeiro
# 28    3
# Name: Tempo Medio, dtype: int64
# paraiso
# 29    2
# Name: Tempo Medio, dtype: int64
# anarosa
# 30    2
# Name: Tempo Medio, dtype: int64
# chacaraklabin
# 31    2
# Name: Tempo Medio, dtype: int64
# santos-imigrantes
# 32    2
# Name: Tempo Medio, dtype: int64
# altodoipiranga
# 33    2
# Name: Tempo Medio, dtype: int64
# estacaosacoma
# 34    2
# Name: Tempo Medio, dtype: int64
# tamanduatei
# 35    2
# Name: Tempo Medio, dtype: int64
# palmeiras–barrafunda
# 37    3
# Name: Tempo Medio, dtype: int64
# marechaldeodoro
# 38    3
# Name: Tempo Medio, dtype: int64
# republica
# 39    3
# Name: Tempo Medio, dtype: int64
# estacaoanhangabau
# 40    3
# Name: Tempo Medio, dtype: int64
# se
# 41    3
# Name: Tempo Medio, dtype: int64
# pedroii
# 42    3
# Name: Tempo Medio, dtype: int64
# bras
# 43    3
# Name: Tempo Medio, dtype: int64
# bresser-mooca
# 44    3
# Name: Tempo Medio, dtype: int64
# belem
# 45    3
# Name: Tempo Medio, dtype: int64
# estacaotatuape
# 46    3
# Name: Tempo Medio, dtype: int64
# carrao
# 47    3
# Name: Tempo Medio, dtype: int64
# penha
# 48    3
# Name: Tempo Medio, dtype: int64
# vilamatilde
# 49    3
# Name: Tempo Medio, dtype: int64
# guilhermina-esperanca
# 50    3
# Name: Tempo Medio, dtype: int64
# patriarca
# 51    3
# Name: Tempo Medio, dtype: int64
# arturalvim
# 52    3
# Name: Tempo Medio, dtype: int64
# luz
# 54    2
# Name: Tempo Medio, dtype: int64
# republica
# 55    2
# Name: Tempo Medio, dtype: int64
# higienópolis-mackenzie
# 56    2
# Name: Tempo Medio, dtype: int64
# paulista
# 57    2
# Name: Tempo Medio, dtype: int64
# oscarfreire
# 58    2
# Name: Tempo Medio, dtype: int64
# fradiquecoutinho
# 59    2
# Name: Tempo Medio, dtype: int64
# farialima
# 60    2
# Name: Tempo Medio, dtype: int64
# pinheiros
# 61    2
# Name: Tempo Medio, dtype: int64
# butanta
# 62    2
# Name: Tempo Medio, dtype: int64
# capaoredondo
# 64    3
# Name: Tempo Medio, dtype: int64
# campolimpo
# 65    3
# Name: Tempo Medio, dtype: int64
# viladasbelezas
# 66    3
# Name: Tempo Medio, dtype: int64
# giovannigronchi
# 67    3
# Name: Tempo Medio, dtype: int64
# santoamaro
# 68    3
# Name: Tempo Medio, dtype: int64
# largotreze
# 69    3
# Name: Tempo Medio, dtype: int64
# adolfopinheiro
# 70    3
# Name: Tempo Medio, dtype: int64
# altodaboavista
# 71    3
# Name: Tempo Medio, dtype: int64
# borbagato
# 72    3
# Name: Tempo Medio, dtype: int64
# brooklin
# 73    3
# Name: Tempo Medio, dtype: int64
# campobelo
# 74    3
# Name: Tempo Medio, dtype: int64
# eucaliptos
# 75    3
# Name: Tempo Medio, dtype: int64
# moema
# 76    3
# Name: Tempo Medio, dtype: int64
# aacd-servidor
# 77    3
# Name: Tempo Medio, dtype: int64
# hospitalsaopaulo
# 78    3
# Name: Tempo Medio, dtype: int64
# santacruz
# 79    3
# Name: Tempo Medio, dtype: int64
# estacaodaluz
# 81    4
# Name: Tempo Medio, dtype: int64
# palmeiras-barrafunda
# 82    4
# Name: Tempo Medio, dtype: int64
# estacaoaguabranca
# 83    4
# Name: Tempo Medio, dtype: int64
# lapa-linha7
# 84    4
# Name: Tempo Medio, dtype: int64
# estacaopiqueri
# 85    4
# Name: Tempo Medio, dtype: int64
# pirituba
# 86    4
# Name: Tempo Medio, dtype: int64
# estacaovilaclarice
# 87    4
# Name: Tempo Medio, dtype: int64
# jaragua
# 88    4
# Name: Tempo Medio, dtype: int64
# vilaaurora
# 89    4
# Name: Tempo Medio, dtype: int64
# estacaoperus
# 90    4
# Name: Tempo Medio, dtype: int64
# caieiras
# 91    4
# Name: Tempo Medio, dtype: int64
# francodarocha
# 92    4
# Name: Tempo Medio, dtype: int64
# estacaobaltazarfidelis
# 93    4
# Name: Tempo Medio, dtype: int64
# franciscomorato
# 94    4
# Name: Tempo Medio, dtype: int64
# estacaobotujuru
# 95    4
# Name: Tempo Medio, dtype: int64
# campolimpopaulista
# 96    4
# Name: Tempo Medio, dtype: int64
# varzeapaulista
# 97    4
# Name: Tempo Medio, dtype: int64
# amadorbueno
# 99    3
# Name: Tempo Medio, dtype: int64
# santarita
# 100    3
# Name: Tempo Medio, dtype: int64
# itapevi
# 101    3
# Name: Tempo Medio, dtype: int64
# engenheirocardoso
# 102    3
# Name: Tempo Medio, dtype: int64
# estacaosagradocoracao
# 103    3
# Name: Tempo Medio, dtype: int64
# jandira
# 104    3
# Name: Tempo Medio, dtype: int64
# jardimsilveira
# 105    3
# Name: Tempo Medio, dtype: int64
# jardimbelval
# 106    3
# Name: Tempo Medio, dtype: int64
# estacaobarueri
# 107    3
# Name: Tempo Medio, dtype: int64
# antôniojoao
# 108    3
# Name: Tempo Medio, dtype: int64
# estacaosantaterezinha
# 109    3
# Name: Tempo Medio, dtype: int64
# carapicuiba
# 110    3
# Name: Tempo Medio, dtype: int64
# estacaogeneralmiguelcosta
# 111    3
# Name: Tempo Medio, dtype: int64
# estacaoquitauna
# 112    3
# Name: Tempo Medio, dtype: int64
# estacaocomandantesampaio
# 113    3
# Name: Tempo Medio, dtype: int64
# osasco
# 114    3
# Name: Tempo Medio, dtype: int64
# estacaopresidentealtino
# 115    3
# Name: Tempo Medio, dtype: int64
# imperatrizleopoldina
# 116    3
# Name: Tempo Medio, dtype: int64
# domingosdemoraes
# 117    3
# Name: Tempo Medio, dtype: int64
# lapa
# 118    3
# Name: Tempo Medio, dtype: int64
# palmeiras–barrafunda
# 119    3
# Name: Tempo Medio, dtype: int64
# grajau
# 121    2
# Name: Tempo Medio, dtype: int64
# primaverainterlagos
# 122    2
# Name: Tempo Medio, dtype: int64
# autódromo
# 123    2
# Name: Tempo Medio, dtype: int64
# jurubatuba
# 124    2
# Name: Tempo Medio, dtype: int64
# socorro
# 125    2
# Name: Tempo Medio, dtype: int64
# joaodias
# 126    2
# Name: Tempo Medio, dtype: int64
# granjajulieta
# 127    2
# Name: Tempo Medio, dtype: int64
# morumbi
# 128    2
# Name: Tempo Medio, dtype: int64
# berrini
# 129    2
# Name: Tempo Medio, dtype: int64
# vilaolimpia
# 130    2
# Name: Tempo Medio, dtype: int64
# cidadejardim
# 131    2
# Name: Tempo Medio, dtype: int64
# hebraica-reboucas
# 132    2
# Name: Tempo Medio, dtype: int64
# cidadeuniversitaria
# 133    2
# Name: Tempo Medio, dtype: int64
# villalobos-jaguare
# 134    2
# Name: Tempo Medio, dtype: int64
# ceasa
# 135    2
# Name: Tempo Medio, dtype: int64
# estacaopresidentealtino
# 136    2
# Name: Tempo Medio, dtype: int64
# riograndedaserra
# 138    3
# Name: Tempo Medio, dtype: int64
# ribeiraopires
# 139    3
# Name: Tempo Medio, dtype: int64
# guapituba
# 140    3
# Name: Tempo Medio, dtype: int64
# maua
# 141    3
# Name: Tempo Medio, dtype: int64
# capuava
# 142    3
# Name: Tempo Medio, dtype: int64
# pref.celsodaniel-santoandre
# 143    3
# Name: Tempo Medio, dtype: int64
# prefeitosaladino
# 144    3
# Name: Tempo Medio, dtype: int64
# utinga
# 145    3
# Name: Tempo Medio, dtype: int64
# saocaetano
# 146    3
# Name: Tempo Medio, dtype: int64
# tamanduatei
# 147    3
# Name: Tempo Medio, dtype: int64
# ipiranga
# 148    3
# Name: Tempo Medio, dtype: int64
# mooca
# 149    3
# Name: Tempo Medio, dtype: int64
# bras
# 150    3
# Name: Tempo Medio, dtype: int64
# estudantes
# 152    3
# Name: Tempo Medio, dtype: int64
# mogidascruzes
# 153    5
# Name: Tempo Medio, dtype: int64
# brazcubas
# 154    3
# Name: Tempo Medio, dtype: int64
# jundiapeba
# 155    5
# Name: Tempo Medio, dtype: int64
# suzano
# 156    7
# Name: Tempo Medio, dtype: int64
# calmonviana
# 157    4
# Name: Tempo Medio, dtype: int64
# poa
# 158    3
# Name: Tempo Medio, dtype: int64
# ferrazdevasconcelos
# 159    4
# Name: Tempo Medio, dtype: int64
# antôniogianettineto
# 160    3
# Name: Tempo Medio, dtype: int64
# guaianazes
# 161    5
# Name: Tempo Medio, dtype: int64
# josebonifacio
# 162    3
# Name: Tempo Medio, dtype: int64
# dombosco
# 163    5
# Name: Tempo Medio, dtype: int64
# corinthians-itaquera
# 164    6
# Name: Tempo Medio, dtype: int64
# tatuape
# 165    10
# Name: Tempo Medio, dtype: int64
# bras
# 166    6
# Name: Tempo Medio, dtype: int64
# calmonviana
# 168    3
# Name: Tempo Medio, dtype: int64
# aracare
# 169    3
# Name: Tempo Medio, dtype: int64
# itaquaquecetuba
# 170    3
# Name: Tempo Medio, dtype: int64
# eng.manoelfeio
# 171    3
# Name: Tempo Medio, dtype: int64
# jardimromano
# 172    3
# Name: Tempo Medio, dtype: int64
# itaimpaulista
# 173    3
# Name: Tempo Medio, dtype: int64
# jardimhelena-vilamara
# 174    3
# Name: Tempo Medio, dtype: int64
# saomiguelpaulista
# 175    3
# Name: Tempo Medio, dtype: int64
# comendadorermelino
# 176    3
# Name: Tempo Medio, dtype: int64
# usp-leste
# 177    3
# Name: Tempo Medio, dtype: int64
# engenheirogoulart
# 178    3
# Name: Tempo Medio, dtype: int64
# tatuape
# 179    3
# Name: Tempo Medio, dtype: int64
# engenheirogoulart
# 181    3
# Name: Tempo Medio, dtype: int64
# guarulhos-cecap
# 182    3
# Name: Tempo Medio, dtype: int64
# saomateus
# 184    3
# Name: Tempo Medio, dtype: int64
# fazendadajuta
# 185    3
# Name: Tempo Medio, dtype: int64
# sapopemba
# 186    3
# Name: Tempo Medio, dtype: int64
# jardimplanalto
# 187    3
# Name: Tempo Medio, dtype: int64
# vilauniao
# 188    3
# Name: Tempo Medio, dtype: int64
# vilatolstoi
# 189    3
# Name: Tempo Medio, dtype: int64
# camilohaddad
# 190    3
# Name: Tempo Medio, dtype: int64
# saolucas
# 191    3
# Name: Tempo Medio, dtype: int64
# oratorio
# 192    3
# Name: Tempo Medio, dtype: int64
# saomateus_o
# 194    10
# Name: Tempo Medio, dtype: int64
# soniamaria
# 195    10
# Name: Tempo Medio, dtype: int64
# santoandre_o
# 196    10
# Name: Tempo Medio, dtype: int64
# saobernardo_o
# 197    10
# Name: Tempo Medio, dtype: int64
# piraporinha
# 200    10
# Name: Tempo Medio, dtype: int64
# diadema_o
# 201    10
# Name: Tempo Medio, dtype: int64
# morumbi_o
# 204    10
# Name: Tempo Medio, dtype: int64
# saobernardo_o
# 198    10
# Name: Tempo Medio, dtype: int64
# diadema_o
# 202    10
# Name: Tempo Medio, dtype: int64
# taboaodaserra_o
# 206    10
# Name: Tempo Medio, dtype: int64
# guarulhos-cecap
# 207    10
# Name: Tempo Medio, dtype: int64
# cecap
# 208    10
# Name: Tempo Medio, dtype: int64
# vilagalvao_o
# 209    10
# Name: Tempo Medio, dtype: int64
# itapevi_o
# 211    10
# Name: Tempo Medio, dtype: int64
# jandira_o
# 212    10
# Name: Tempo Medio, dtype: int64
# carapicuiba_o
# 213    10
# Name: Tempo Medio, dtype: int64
# generalmiguelcosta_o
# 214    10
# Name: Tempo Medio, dtype: int64
# amadoraguiar_o
# 215    10
# Name: Tempo Medio, dtype: int64

# %%
pontes_inter_reg = {# sul 
                    "bras" : ["3 - Vermelha SP","10 - Turquesa","11 - Coral"],
                    # centro oeste
                    "se" : [],
                    "luz" : ["RO AM PA TO"]}

# %%
metroSP = nx.DiGraph()

# compondo regioes
for g in dic_grafos.values():
    
    metroSP = nx.compose(metroSP, g)

# %%
dic_grafos_pos_total = {}
    # compondo regioes
for g in dic_grafos_pos.values():
    dic_grafos_pos_total.update(g)

# %%
    # pos = dic_grafos_pos[nomeLinha]
    # print(pos)
    # top = nx.bipartite.sets(g)[0]
    # pos = nx.bipartite_layout(g, top)
    #nx.draw_networkx_labels(g, label_pos=, pos=pos, rotation='vertical')
   
    # print(dic_grafos_pos_total)
    nx.draw_networkx(metroSP, pos=dic_grafos_pos_total, node_color='blue', node_size=20, font_color='gray',with_labels=True)
    # Set margins for the axes so that nodes aren't clipped
    ax = plt.gca()
    
    ax.margins(0.20)
    fig= plt.gcf()
    fig.set_size_inches(40, 20.5)
    plt.axis("off")
    plt.show()

# %%
de = "grajau"  # str(input("Digita a estação onde voce está:"))
para = "aeroporto-guarulhos" #str(input("Digita a estação onde voce vai:"))
gg = nx.dijkstra_path(metroSP,de,para,weight='weight')
gg
dfViagem = df[df['estacao'].apply(lambda x: x in gg)]
tempo_da_viagem = df['Tempo Medio'].sum()
print(f"de {de} para {para} demora {tempo_da_viagem}")
# print(gg)

dfV = pd.DataFrame(gg, columns=['estacao'])
df_merge = pd.merge(dfV, df, on='estacao')
#df_merge = df_merge.groupby(['estacao']).max()
df_merge
# Out:
# de grajau para aeroporto-guarulhos demora 788
#                     estacao  ordem  Tempo Medio          linha    tipo  \
# 0                    grajau      1            2  9 - Esmeralda    CPTM
# 1       primaverainterlagos      2            2  9 - Esmeralda    CPTM
# 2                 autódromo      3            2  9 - Esmeralda    CPTM
# 3                jurubatuba      4            2  9 - Esmeralda    CPTM
# 4                   socorro      5            2  9 - Esmeralda    CPTM
# 5                  joaodias      6            2  9 - Esmeralda    CPTM
# 6             granjajulieta      7            2  9 - Esmeralda    CPTM
# 7                   morumbi      8            2  9 - Esmeralda    CPTM
# 8                   berrini      9            2  9 - Esmeralda    CPTM
# 9               vilaolimpia     10            2  9 - Esmeralda    CPTM
# 10             cidadejardim     11            2  9 - Esmeralda    CPTM
# 11        hebraica-reboucas     12            2  9 - Esmeralda    CPTM
# 12      cidadeuniversitaria     13            2  9 - Esmeralda    CPTM
# 13       villalobos-jaguare     14            2  9 - Esmeralda    CPTM
# 14                    ceasa     15            2  9 - Esmeralda    CPTM
# 15  estacaopresidentealtino      6            3      8 - Cinza    CPTM
# 16  estacaopresidentealtino     16            2  9 - Esmeralda    CPTM
# 17     imperatrizleopoldina      5            3      8 - Cinza    CPTM
# 18         domingosdemoraes      4            3      8 - Cinza    CPTM
# 19                     lapa      3            3      8 - Cinza    CPTM
# 20     palmeiras–barrafunda      1            3   3 - Vermelha   Metrô
# 21     palmeiras–barrafunda      2            3      8 - Cinza    CPTM
# 22          marechaldeodoro      2            3   3 - Vermelha   Metrô
# 23                republica      3            3   3 - Vermelha   Metrô
# 24                republica      2            2    4 - Amarela   Metro
# 25                      luz      9            2       1 - Azul   Metro
# 26                      luz      1            2    4 - Amarela   Metro
# 27                      luz     14            3  10 - Turquesa    CPTM
# 28                      luz     16            4     11 - Coral    CPTM
# 29                     bras      7            3   3 - Vermelha   Metrô
# 30                     bras     13            3  10 - Turquesa    CPTM
# 31                     bras     15            6     11 - Coral    CPTM
# 32                     bras     13            3    12 - Safira    CPTM
# 33                  tatuape     14           10     11 - Coral    CPTM
# 34                  tatuape     12            3    12 - Safira    CPTM
# 35        engenheirogoulart     11            3    12 - Safira    CPTM
# 36        engenheirogoulart      1            3      13 - Jade    CPTM
# 37          guarulhos-cecap      2            3      13 - Jade    CPTM
# 38          guarulhos-cecap      2           10   Corredor - B    EMTU
# 39      aeroporto-guarulhos      3            3      13 - Jade    CPTM
#
#           lat       long
# 0  -23.736335 -46.696976
# 1  -23.722580 -46.691758
# 2  -23.706088 -46.688363
# 3  -23.677132 -46.702087
# 4  -23.663435 -46.710843
# 5  -23.638771 -46.722713
# 6  -23.627239 -46.711883
# 7  -23.621780 -46.701092
# 8  -23.604754 -46.696134
# 9  -23.593457 -46.691932
# 10 -23.585169 -46.691155
# 11 -23.572908 -46.698082
# 12 -23.556625 -46.711376
# 13 -23.545999 -46.732699
# 14 -23.536993 -46.742600
# 15 -23.529981 -46.767096
# 16 -23.530581 -46.761904
# 17 -23.527425 -46.744548
# 18 -23.522429 -46.728994
# 19 -23.520047 -46.717445
# 20 -23.525413 -46.667388
# 21 -23.527910 -46.667574
# 22 -23.533250 -46.655600
# 23 -23.543349 -46.642248
# 24 -23.543567 -46.642428
# 25 -23.535955 -46.634338
# 26 -23.535746 -46.635397
# 27 -23.536464 -46.636459
# 28 -23.536464 -46.636459
# 29 -23.547355 -46.616059
# 30 -23.547860 -46.618064
# 31 -23.547860 -46.618064
# 32 -23.547860 -46.618064
# 33 -23.540272 -46.578783
# 34 -23.540272 -46.578783
# 35 -23.497917 -46.523141
# 36 -23.498084 -46.521952
# 37 -23.447434 -46.495902
# 38 -23.430968 -46.490741
# 39 -23.432472 -46.495579

# %%
df_merge
# Out:
#                     estacao  ordem  Tempo Medio          linha    tipo  \
# 0                    grajau      1            2  9 - Esmeralda    CPTM
# 1       primaverainterlagos      2            2  9 - Esmeralda    CPTM
# 2                 autódromo      3            2  9 - Esmeralda    CPTM
# 3                jurubatuba      4            2  9 - Esmeralda    CPTM
# 4                   socorro      5            2  9 - Esmeralda    CPTM
# 5                  joaodias      6            2  9 - Esmeralda    CPTM
# 6             granjajulieta      7            2  9 - Esmeralda    CPTM
# 7                   morumbi      8            2  9 - Esmeralda    CPTM
# 8                   berrini      9            2  9 - Esmeralda    CPTM
# 9               vilaolimpia     10            2  9 - Esmeralda    CPTM
# 10             cidadejardim     11            2  9 - Esmeralda    CPTM
# 11        hebraica-reboucas     12            2  9 - Esmeralda    CPTM
# 12      cidadeuniversitaria     13            2  9 - Esmeralda    CPTM
# 13       villalobos-jaguare     14            2  9 - Esmeralda    CPTM
# 14                    ceasa     15            2  9 - Esmeralda    CPTM
# 15  estacaopresidentealtino      6            3      8 - Cinza    CPTM
# 16  estacaopresidentealtino     16            2  9 - Esmeralda    CPTM
# 17     imperatrizleopoldina      5            3      8 - Cinza    CPTM
# 18         domingosdemoraes      4            3      8 - Cinza    CPTM
# 19                     lapa      3            3      8 - Cinza    CPTM
# 20     palmeiras–barrafunda      1            3   3 - Vermelha   Metrô
# 21     palmeiras–barrafunda      2            3      8 - Cinza    CPTM
# 22          marechaldeodoro      2            3   3 - Vermelha   Metrô
# 23                republica      3            3   3 - Vermelha   Metrô
# 24                republica      2            2    4 - Amarela   Metro
# 25                      luz      9            2       1 - Azul   Metro
# 26                      luz      1            2    4 - Amarela   Metro
# 27                      luz     14            3  10 - Turquesa    CPTM
# 28                      luz     16            4     11 - Coral    CPTM
# 29                     bras      7            3   3 - Vermelha   Metrô
# 30                     bras     13            3  10 - Turquesa    CPTM
# 31                     bras     15            6     11 - Coral    CPTM
# 32                     bras     13            3    12 - Safira    CPTM
# 33                  tatuape     14           10     11 - Coral    CPTM
# 34                  tatuape     12            3    12 - Safira    CPTM
# 35        engenheirogoulart     11            3    12 - Safira    CPTM
# 36        engenheirogoulart      1            3      13 - Jade    CPTM
# 37          guarulhos-cecap      2            3      13 - Jade    CPTM
# 38          guarulhos-cecap      2           10   Corredor - B    EMTU
# 39      aeroporto-guarulhos      3            3      13 - Jade    CPTM
#
#           lat       long
# 0  -23.736335 -46.696976
# 1  -23.722580 -46.691758
# 2  -23.706088 -46.688363
# 3  -23.677132 -46.702087
# 4  -23.663435 -46.710843
# 5  -23.638771 -46.722713
# 6  -23.627239 -46.711883
# 7  -23.621780 -46.701092
# 8  -23.604754 -46.696134
# 9  -23.593457 -46.691932
# 10 -23.585169 -46.691155
# 11 -23.572908 -46.698082
# 12 -23.556625 -46.711376
# 13 -23.545999 -46.732699
# 14 -23.536993 -46.742600
# 15 -23.529981 -46.767096
# 16 -23.530581 -46.761904
# 17 -23.527425 -46.744548
# 18 -23.522429 -46.728994
# 19 -23.520047 -46.717445
# 20 -23.525413 -46.667388
# 21 -23.527910 -46.667574
# 22 -23.533250 -46.655600
# 23 -23.543349 -46.642248
# 24 -23.543567 -46.642428
# 25 -23.535955 -46.634338
# 26 -23.535746 -46.635397
# 27 -23.536464 -46.636459
# 28 -23.536464 -46.636459
# 29 -23.547355 -46.616059
# 30 -23.547860 -46.618064
# 31 -23.547860 -46.618064
# 32 -23.547860 -46.618064
# 33 -23.540272 -46.578783
# 34 -23.540272 -46.578783
# 35 -23.497917 -46.523141
# 36 -23.498084 -46.521952
# 37 -23.447434 -46.495902
# 38 -23.430968 -46.490741
# 39 -23.432472 -46.495579

# %%
px.set_mapbox_access_token(open("datasets/.mapbox_token").read())

# %%
start = df_merge.iloc[[0]]
end = df_merge.iloc[[-1]]

# %%
df_merge.head(1)
# Out:
#   estacao  ordem  Tempo Medio          linha  tipo        lat       long
# 0  grajau      1            2  9 - Esmeralda  CPTM -23.736335 -46.696976

# %%
prevEst = start['estacao'].values[0]
prevLinhaEst = start['linha'].values[0]

print(f"Inicia sua viagem na estação {start['estacao'].values[0]}")

for i,est in df_merge[1:-1].iterrows():
    # print(est[0])
    if (prevLinhaEst != est[0]) and (prevEst != est[3]):
        print(f"Desce na estação {est[0]} e faz baldeação para a  linha {est[3]}")
    prevEst = est[3]
    prevLinhaEst = est[0]
print(f"Voce chegou a seu destino desce na estação {end['estacao'].values[0]}")
# Out:
# Inicia sua viagem na estação grajau
# Desce na estação primaverainterlagos e faz baldeação para a  linha 9 - Esmeralda
# Desce na estação estacaopresidentealtino e faz baldeação para a  linha 8 - Cinza
# Desce na estação imperatrizleopoldina e faz baldeação para a  linha 8 - Cinza
# Desce na estação palmeiras–barrafunda e faz baldeação para a  linha 3 - Vermelha
# Desce na estação marechaldeodoro e faz baldeação para a  linha 3 - Vermelha
# Desce na estação luz e faz baldeação para a  linha 1 - Azul
# Desce na estação bras e faz baldeação para a  linha 3 - Vermelha
# Desce na estação tatuape e faz baldeação para a  linha 11 - Coral
# Voce chegou a seu destino desce na estação aeroporto-guarulhos

# %% [markdown]
# https://shakasom.medium.com/routing-street-networks-find-your-way-with-python-9ba498147342

# %%
fig = px.scatter_mapbox(dfViagem, lat="lat", lon="long", size_max=100,
                        hover_name="estacao", zoom=11, height=500, mapbox_style="dark")
                        #animation_frame=dfViagem.index,
# fig.data[0].marker = dict(size = 12, color="blue")

# fig.add_trace(px.scatter_mapbox(start, lon= "lat", lat="long").data[0])

# fig.data[1].marker = dict(size = 15, color="red")

# fig.add_trace(px.scatter_mapbox(end, lon= "lat", lat="long").data[0])

# fig.data[2].marker = dict(size = 15, color="green")

fig.add_trace(px.line_mapbox(dfViagem, lon= "lat", lat="long").data[0])

# fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
